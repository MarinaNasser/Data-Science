# %% [markdown]
# # Assignment 2

# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
df = pd.read_csv('/content/Student_Marks.csv')
df.head()
# Out:
#    number_courses  time_study   Marks
# 0               3       4.508  19.202
# 1               4       0.096   7.734
# 2               4       3.133  13.811
# 3               6       7.909  53.018
# 4               8       7.811  55.299

# %% [markdown]
# ## Convert the "Marks" column to numpy array
# #### Hint : You will use to to_numpy()

# %%
marks = df['Marks'].to_numpy()
marks
# Out:
# array([19.202,  7.734, 13.811, 53.018, 55.299, 17.822, 29.889, 17.264,
#        20.348, 30.862, 42.036, 12.132, 24.318, 17.672, 11.397, 19.466,
#        30.548, 38.49 , 50.986, 25.133, 22.073, 35.939, 12.209, 28.043,
#        16.517,  6.623, 12.647, 26.532,  9.333,  8.837, 24.172,  8.1  ,
#        15.038, 39.965, 17.171, 43.978, 13.119, 46.453, 41.358, 51.142,
#         7.336, 15.725, 19.771, 10.429,  9.742,  8.924, 16.703, 22.701,
#        26.882, 19.106, 40.602, 22.184,  7.892, 36.653, 53.158, 18.238,
#        53.359, 51.583, 31.236, 51.343, 10.522, 10.844, 19.59 , 21.379,
#        12.591, 13.562, 27.569,  6.185,  8.92 , 21.4  , 16.606, 13.416,
#        20.398,  7.014, 39.952,  6.217, 36.746, 38.278, 49.544,  6.349,
#        54.321, 17.705, 44.099, 16.106, 16.461, 39.957, 23.149,  6.053,
#        11.253, 40.024, 24.394, 19.564, 23.916, 42.426, 24.451, 19.128,
#         5.609, 41.444, 12.027, 32.357])

# %% [markdown]
# ## Filter the students who studies 4 hours or less in two diffrent ways

# %%
df[df['time_study'] <= 4]
# Out:
#     number_courses  time_study   Marks
# 1                4       0.096   7.734
# 2                4       3.133  13.811
# 5                6       3.211  17.822
# 7                5       3.413  17.264
# 11               7       0.423  12.132
# 14               3       2.908  11.397
# 19               8       3.977  25.133
# 22               5       2.051  12.209
# 24               4       3.635  16.517
# 25               3       1.407   6.623
# 26               7       0.508  12.647
# 28               5       0.156   9.333
# 29               4       1.299   8.837
# 30               8       3.864  24.172
# 31               3       1.923   8.100
# 32               8       0.932  15.038
# 36               4       2.966  13.119
# 40               4       0.140   7.336
# 41               6       2.754  15.725
# 42               6       3.591  19.771
# 43               5       1.557  10.429
# 44               4       1.954   9.742
# 45               3       2.061   8.924
# ...

# %%
df[df['time_study'].apply(lambda x : x <= 4)]
# Out:
#     number_courses  time_study   Marks
# 1                4       0.096   7.734
# 2                4       3.133  13.811
# 5                6       3.211  17.822
# 7                5       3.413  17.264
# 11               7       0.423  12.132
# 14               3       2.908  11.397
# 19               8       3.977  25.133
# 22               5       2.051  12.209
# 24               4       3.635  16.517
# 25               3       1.407   6.623
# 26               7       0.508  12.647
# 28               5       0.156   9.333
# 29               4       1.299   8.837
# 30               8       3.864  24.172
# 31               3       1.923   8.100
# 32               8       0.932  15.038
# 36               4       2.966  13.119
# 40               4       0.140   7.336
# 41               6       2.754  15.725
# 42               6       3.591  19.771
# 43               5       1.557  10.429
# 44               4       1.954   9.742
# 45               3       2.061   8.924
# ...

# %% [markdown]
# ## Find the mean and meadian of " Marks"

# %%
# mean
df['Marks'].mean()
# Out:
# 24.417689999999993

# %%
# meadian
df['Marks'].median()
# Out:
# 20.0595

# %% [markdown]
# ## Is the data in " Marks" normally distributed? why? why not?

# %% [markdown]
# ###### Answer: no because we find mean bigger than medain

# %% [markdown]
# ## If the data isn't normally distribtued, what is the distribution?

# %% [markdown]
# ###### Answer: skewed right

# %% [markdown]
# ## Make a list wiht the name "id".The list should countain the numbers from 20200400 to 20200499

# %%
id = [i for i in range(20200400, 20200500)]
id[:5]
# Out:
# [20200400, 20200401, 20200402, 20200403, 20200404]

# %% [markdown]
# ## Convert the id list to a DataFrame

# %%
id_df = pd.DataFrame(id)
id_df.head()
# Out:
#           0
# 0  20200400
# 1  20200401
# 2  20200402
# 3  20200403
# 4  20200404

# %% [markdown]
# ## Creat a column called "ID" and make it contains the values of the previous id DataFrame

# %%
df['ID'] = id
df.head()
# Out:
#    number_courses  time_study   Marks        ID
# 0               3       4.508  19.202  20200400
# 1               4       0.096   7.734  20200401
# 2               4       3.133  13.811  20200402
# 3               6       7.909  53.018  20200403
# 4               8       7.811  55.299  20200404

# %% [markdown]
# ##  Set the index using ID column

# %%
df.set_index('ID', inplace=True)
df.head()
# Out:
#           number_courses  time_study   Marks
# ID
# 20200400               3       4.508  19.202
# 20200401               4       0.096   7.734
# 20200402               4       3.133  13.811
# 20200403               6       7.909  53.018
# 20200404               8       7.811  55.299

# %% [markdown]
# ## Get the number of courses from 20200420 to 20200444 using loc function:

# %%
df.loc[20200420:20200444]
# Out:
#           number_courses  time_study   Marks
# ID
# 20200420               4       4.733  22.073
# 20200421               6       6.126  35.939
# 20200422               5       2.051  12.209
# 20200423               7       4.875  28.043
# 20200424               4       3.635  16.517
# 20200425               3       1.407   6.623
# 20200426               7       0.508  12.647
# 20200427               8       4.378  26.532
# 20200428               5       0.156   9.333
# 20200429               4       1.299   8.837
# 20200430               8       3.864  24.172
# 20200431               3       1.923   8.100
# 20200432               8       0.932  15.038
# 20200433               6       6.594  39.965
# 20200434               3       4.083  17.171
# 20200435               3       7.543  43.978
# 20200436               4       2.966  13.119
# 20200437               6       7.283  46.453
# 20200438               7       6.533  41.358
# 20200439               6       7.775  51.142
# ...
